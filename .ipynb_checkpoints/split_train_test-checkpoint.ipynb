# %%
from datasets import Dataset
seed = 42
# Out:
# <function datasets.arrow_dataset.Dataset.from_parquet(path_or_paths: Union[str, bytes, os.PathLike, list[Union[str, bytes, os.PathLike]]], split: Optional[datasets.splits.NamedSplit] = None, features: Optional[datasets.features.features.Features] = None, cache_dir: str = None, keep_in_memory: bool = False, columns: Optional[list[str]] = None, num_proc: Optional[int] = None, **kwargs)>

# %%
ds = Dataset.from_parquet('/home/ccm/datasets/data/train-00000-of-00001.parquet')
# Out:
# Generating train split: 20548 examples [00:00, 56184.47 examples/s]

# %%
print(len(ds))
print(ds[:2])
# Out:
# 20548
# ...

# %%
ds_split = ds.train_test_split(test_size=0.1, seed=42)
print(ds_split)
train_ds = ds['train']
test_ds = ds['test']
print(len(train_ds))
print(len(test_ds))
# print(len(ds))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 ds_split = ds.train_test_split(test_size=0.1, seed=42)
# ----> 2 train_ds = ds['train']
#       3 test_ds = ds['test']
#       4 print(len(train_ds))
#
# File ~/anaconda3/envs/transformers/lib/python3.12/site-packages/datasets/arrow_dataset.py:2858, in Dataset.__getitem__(self, key)
#    2856 if isinstance(key, str):
#    2857     if self._format_type is None or self._format_type not in ("arrow", "pandas", "polars"):
# -> 2858         return Column(self, key)
#    2859 return self._getitem(key)
#
# File ~/anaconda3/envs/transformers/lib/python3.12/site-packages/datasets/arrow_dataset.py:658, in Column.__init__(self, source, column_name)
#     656 self.column_name = column_name
#     657 if not isinstance(source.features, dict) or column_name not in source.features:
# ...
